# %%
import pandas as pd
import numpy as np
# import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.neural_network import MLPRegressor
from sklearn import metrics

# %%
econ_df = pd.read_csv(
    "Resources/Refined Data Set.csv"
)

econ_df
# Out:
#     Time  GDP/capita growth (%)  Access to electricity  \
# 0   1993               2.357339              89.318225
# 1   1994               3.575111              90.223083
# 2   1995              -0.841473              88.599506
# 3   1996               2.367651              89.557909
# 4   1997               3.620615              90.015864
# 5   1998               1.059776              90.636887
# 6   1999              -0.865684              91.247588
# 7   2000               2.058134              91.725741
# 8   2001              -0.919453              92.342229
# 9   2002              -0.832495              92.646073
# 10  2003               1.216159              92.739120
# 11  2004               4.257426              93.226985
# 12  2005               2.731720              93.553600
# 13  2006               3.812768              94.268651
# 14  2007               4.078821              94.496909
# 15  2008               2.574894              95.230451
# ...

# %%
# Creating the X and y sets
y = econ_df["GDP/capita growth (%)"]
X = econ_df.drop(columns=["GDP/capita growth (%)"])

# %%
# Split the data into traning and testing sets using the train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Give feature names to X_train_scaled and X_test_scaled

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_train_scaled_df[0:1]
# Out:
#         Time  Access to electricity  Literacy rate (adult female)  \
# 21  1.067585               1.118474                      1.110791
#
#     Literacy rate (youth female)  Literacy rate (youth male)  \
# 21                      1.136749                    1.107533
#
#     Literacy rate (adult male)  Life expectancy at birth (female)  \
# 21                    1.053092                           1.086996
#
#     Life expectancy at birth (\male)  Primary school enrollment (net%)  \
# 21                          1.172693                          0.057429
#
#     Labor force participation rate (female%)  \
# 21                                 -1.554338
#
#     Labor force participation rate (male%)  Net migration
# 21                               -1.257306       1.063901

# %%
X_test_scaled_df = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)
X_test_scaled_df[0:1]
# Out:
#         Time  Access to electricity  Literacy rate (adult female)  \
# 17  0.576741               0.728746                      0.564002
#
#     Literacy rate (youth female)  Literacy rate (youth male)  \
# 17                      0.661048                    0.612024
#
#     Literacy rate (adult male)  Life expectancy at birth (female)  \
# 17                    0.671795                           0.522004
#
#     Life expectancy at birth (\male)  Primary school enrollment (net%)  \
# 17                          0.554368                           1.16679
#
#     Labor force participation rate (female%)  \
# 17                                 -0.132386
#
#     Labor force participation rate (male%)  Net migration
# 17                                -0.63272       0.670442

# %%
mlp_r = MLPRegressor(hidden_layer_sizes=(24,24,24), max_iter=1000, activation='identity', solver='adam')
mlp_r.fit(X_train_scaled_df, y_train)
# Out:
# MLPRegressor(activation='identity', hidden_layer_sizes=(24, 24, 24),
#              max_iter=1000)

# %%
y_pred = mlp_r.predict(X_test_scaled_df)
y_pred
# Out:
# array([2.01999416, 2.65739623, 1.2279401 , 1.42458754, 1.52844112,
#        0.6417865 , 1.92069198])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred) 
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
std = np.std(y_test)

print(f"r^2 Score: {r2}.") 
print(f"Mean Squared Error: {mse}.") 
print(f"Root Mean Squared Error: {rmse}.") 
print(f"Standard Deviation: {std}.")
# Out:
# r^2 Score: 0.03780985959054295.
# Mean Squared Error: 3.6587745734770505.
# Root Mean Squared Error: 1.9127923498061807.
# Standard Deviation: 1.9500124087691886.

# %%
plt.plot(mlp_r.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()

# %%
from sklearn.inspection import PartialDependenceDisplay

fig_lr_a, ax = plt.subplots(figsize=(12, 6))
ax.set_title("Multi-layer Perceptron 1")
mlp_disp = PartialDependenceDisplay.from_estimator(
    mlp_r, X, ["Literacy rate (adult male)", "Literacy rate (adult female)"], ax=ax, line_kw={"color": "red"})

# %%
fig_lr_y, ax = plt.subplots(figsize=(12, 6))
ax.set_title("Multi-layer Perceptron 2")
mlp_disp = PartialDependenceDisplay.from_estimator(
    mlp_r, X, ["Literacy rate (youth male)", "Literacy rate (youth female)"], ax=ax, line_kw={"color": "red"})

# %%
fig_le, ax = plt.subplots(figsize=(12, 6))
ax.set_title("Multi-layer Perceptron 3")
mlp_disp = PartialDependenceDisplay.from_estimator(
    mlp_r, X, ["Life expectancy at birth (\male)", "Life expectancy at birth (female)"], ax=ax, line_kw={"color": "red"})

# %%
fig_lfpr, ax = plt.subplots(figsize=(12, 6))
ax.set_title("Multi-layer Perceptron 4")
mlp_disp = PartialDependenceDisplay.from_estimator(
    mlp_r, X, ["Labor force participation rate (male%)", "Labor force participation rate (female%)"], ax=ax, line_kw={"color": "red"})

# %%
mlp_t_disp = PartialDependenceDisplay.from_estimator(mlp_r, X, ["Time"])
mlp_ae_disp = PartialDependenceDisplay.from_estimator(mlp_r, X, ["Access to electricity"])
mlp_se_disp = PartialDependenceDisplay.from_estimator(mlp_r, X, ["Primary school enrollment (net%)"])
mlp_nm_disp = PartialDependenceDisplay.from_estimator(mlp_r, X, ["Net migration"])

# %%
# coefs = mlp_r.coefs_
coefs = mlp_r.coefs_
ints = mlp_r.intercepts_

# print(coefs)
print(coefs[0].shape)
print(coefs[1].shape)
print(coefs[2].shape)
print(coefs[3].shape)
print("---")
print(ints[0].shape)
print(ints[1].shape)
print(ints[2].shape)
print(ints[3].shape)
# Out:
# (12, 24)
# (24, 24)
# (24, 24)
# (24, 1)
# ---
# (24,)
# (24,)
# (24,)
# (1,)

# %%
l0_weights_df = pd.DataFrame(coefs[0])
l1_weights_df = pd.DataFrame(coefs[1])
l2_weights_df = pd.DataFrame(coefs[2])
l3_weights_df = pd.DataFrame(coefs[3])

l0_bias_df = pd.DataFrame(ints[0])
l1_bias_df = pd.DataFrame(ints[1])
l2_bias_df = pd.DataFrame(ints[2])
l3_bias_df = pd.DataFrame(ints[3])

# %%
l0_weights_df.to_csv('Models/Weights/Layer_0.csv', index=False)
l1_weights_df.to_csv('Models/Weights/Layer_1.csv', index=False)
l2_weights_df.to_csv('Models/Weights/Layer_2.csv', index=False)
l3_weights_df.to_csv('Models/Weights/Layer_3.csv', index=False)

l0_bias_df.to_csv('Models/Biases/Layer_0.csv', index=False)
l1_bias_df.to_csv('Models/Biases/Layer_1.csv', index=False)
l2_bias_df.to_csv('Models/Biases/Layer_2.csv', index=False)
l3_bias_df.to_csv('Models/Biases/Layer_3.csv', index=False)
